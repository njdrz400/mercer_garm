# %%
import os
import yaml
from launch import LaunchDescription
from launch.actions import ExecuteProcess, DeclareLaunchArgument
from launch.substitutions import LaunchConfiguration
from launch_ros.actions import Node, SetParameter
from ament_index_python.packages import get_package_share_directory
from moveit_configs_utils import MoveItConfigsBuilder

# %%
def load_yaml(package_name, file_path):
        package_path = get_package_share_directory(package_name)
        absolute_file_path = os.path.join(package_path, file_path)

        try:
                with open(absolute_file_path, 'r') as file:
                    return yaml.safe_load(file)
        except EnvironmentError:  # parent of IOError, OSError *and* WindowsError where available
                return None

# %%
start_servo = LaunchConfiguration('start_servo')

start_servo_arg = DeclareLaunchArgument(
        'start_servo',
        default_value='false',
        description='Start the servo node.')

# %%
moveit_config = (
        MoveItConfigsBuilder(
                robot_name="panda", package_name="moveit_resources_panda_moveit_config"
        )
        .robot_description(file_path="/home/scott/ros2_ws/src/g-arm/ros2/g_arm_description/urdf/robot.urdf.xacro")
        .trajectory_execution(file_path="/home/scott/ros2_ws/src/g-arm/ros2/g_arm_moveit2/config/g_arm_servo_config.yaml")
        .moveit_cpp(
                file_path=os.path.join(
                        get_package_share_directory("g-demo_demos"),
                        "config",
                        "jupyter_notebook_prototyping.yaml"
                )
        )
        .to_moveit_configs()
)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File /opt/ros/jazzy/lib/python3.12/site-packages/ament_index_python/packages.py:60, in get_package_prefix(package_name)
#      59 try:
# ---> 60     content, package_prefix = get_resource('packages', package_name)
#      61 except LookupError:
#
# File /opt/ros/jazzy/lib/python3.12/site-packages/ament_index_python/resources.py:92, in get_resource(resource_type, resource_name)
#      91         return content, path
# ---> 92 raise LookupError(
#      93     "Could not find the resource '%s' of type '%s'" % (resource_name, resource_type))
#
# LookupError: Could not find the resource 'g-demo_demos' of type 'packages'
#
# During handling of the above exception, another exception occurred:
#
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[16], line 9
#       1 moveit_config = (
#       2         MoveItConfigsBuilder(
#       3                 robot_name="panda", package_name="moveit_resources_panda_moveit_config"
#       4         )
#       5         .robot_description(file_path="/home/scott/ros2_ws/src/g-arm/ros2/g_arm_description/urdf/robot.urdf.xacro")
#       6         .trajectory_execution(file_path="/home/scott/ros2_ws/src/g-arm/ros2/g_arm_moveit2/config/g_arm_servo_config.yaml")
#       7         .moveit_cpp(
#       8                 file_path=os.path.join(
# ----> 9                         get_package_share_directory("g-demo_demos"),
#      10                         "config",
#      11                         "jupyter_notebook_prototyping.yaml"
#      12                 )
#      13         )
#      14         .to_moveit_configs()
#      15 )
#
# File /opt/ros/jazzy/lib/python3.12/site-packages/ament_index_python/packages.py:82, in get_package_share_directory(package_name, print_warning)
#      67 def get_package_share_directory(package_name: str, print_warning: bool = True) -> str:
#      68     """
#      69     Return the share directory of the given package.
#      70
#    (...)     80     :raises: :exc:`ValueError` if the package name is invalid
#      81     """
# ---> 82     path = os.path.join(get_package_prefix(package_name), 'share', package_name)
#      83     if print_warning and not os.path.exists(path):
#      84         warnings.warn(f'Share directory for {package_name} ({path}) does not exist.', stacklevel=2)
#
# File /opt/ros/jazzy/lib/python3.12/site-packages/ament_index_python/packages.py:62, in get_package_prefix(package_name)
#      60     content, package_prefix = get_resource('packages', package_name)
#      61 except LookupError:
# ---> 62     raise PackageNotFoundError(
#      63         "package '{}' not found, searching: {}".format(package_name, get_search_paths()))
#      64 return package_prefix
#
# PackageNotFoundError: "package 'g-demo_demos' not found, searching: ['/home/scott/ws_moveit/install/robotiq_hardware_tests', '/home/scott/ws_moveit/install/robotiq_driver', '/home/scott/ws_moveit/install/serial', '/home/scott/ws_moveit/install/moveit_visual_tools', '/home/scott/ws_moveit/install/rviz_visual_tools', '/home/scott/ws_moveit/install/rviz_marker_tools', '/home/scott/ws_moveit/install/kortex_bringup', '/home/scott/ws_moveit/install/kinova_gen3_lite_moveit_config', '/home/scott/ws_moveit/install/kinova_gen3_7dof_robotiq_2f_85_moveit_config', '/home/scott/ws_moveit/install/kinova_gen3_6dof_robotiq_2f_85_moveit_config', '/home/scott/ws_moveit/install/kortex_description', '/home/scott/ws_moveit/install/robotiq_description', '/home/scott/ws_moveit/install/robotiq_controllers', '/home/scott/ws_moveit/install/moveit_task_constructor_msgs', '/home/scott/ws_moveit/install/moveit_resources', '/home/scott/ws_moveit/install/moveit_resources_pr2_description', '/home/scott/ws_moveit/install/moveit_resources_panda_moveit_config', '/home/scott/ws_moveit/install/dual_arm_panda_moveit_config', '/home/scott/ws_moveit/install/moveit_resources_panda_description', '/home/scott/ws_moveit/install/moveit_resources_fanuc_moveit_config', '/home/scott/ws_moveit/install/moveit_resources_fanuc_description', '/home/scott/ws_moveit/install/moveit_msgs', '/home/scott/ws_moveit/install/moveit_common', '/home/scott/ws_moveit/install/kortex_driver', '/home/scott/ws_moveit/install/kortex_api', '/home/scott/ros2_ws/install/rviz_marker_tools', '/home/scott/ros2_ws/install/pymoveit2', '/home/scott/ros2_ws/install/moveit_task_constructor_msgs', '/home/scott/ros2_ws/install/joy_js_pkg', '/home/scott/ros2_ws/install/g_arm_python_examples', '/home/scott/ros2_ws/install/g-arm_simulation', '/home/scott/ros2_ws/install/g_arm_moveit2', '/home/scott/ros2_ws/install/g_arm_description', '/home/scott/ros2_ws/install/g_arm', '/opt/ros/jazzy']"
